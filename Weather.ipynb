# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
fire_file="Resources/FW_Veg_Rem_Combined.csv"
fire_df=pd.read_csv(fire_file)
fire_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 fire_name  fire_size fire_size_class  \
# 0           0             0       NaN       10.0               C
# 1           1             1       NaN        3.0               B
# 2           2             2       NaN       60.0               C
# 3           3             3    WNA  1        1.0               B
# 4           4             4       NaN        2.0               B
#
#     stat_cause_descr   latitude   longitude state disc_clean_date  ...  \
# 0  Missing/Undefined  18.105072  -66.753044    PR       2/11/2007  ...
# 1              Arson  35.038330  -87.610000    TN      12/11/2006  ...
# 2              Arson  34.947800  -88.722500    MS       2/29/2004  ...
# 3     Debris Burning  39.641400 -119.308300    NV        6/6/2005  ...
# 4      Miscellaneous  30.700600  -90.591400    LA       9/22/1999  ...
#
#   Wind_cont Hum_pre_30 Hum_pre_15  Hum_pre_7   Hum_cont Prec_pre_30  \
# 0  3.250413  78.216590  76.793750  76.381579  78.724370         0.0
# ...

# %%
##Data Cleaning
#Gathering records from California, greater than or equal to 10 acres, and with valid weather data
fire_df=fire_df.loc[(fire_df["state"]=="CA")&
                    (fire_df["fire_size"]>=10)&
                    (fire_df["weather_file"]!="File Not Found")&
                    (fire_df["Temp_pre_30"]!=0)&
                    (fire_df["Temp_pre_15"]!=0)&
                    (fire_df["Temp_pre_7"]!=0)&
                    (fire_df["Temp_cont"]!=0)]

#dropping unneeded columns
fire_df=fire_df.drop(columns=["Unnamed: 0",
                              "Unnamed: 0.1",
                              "state",
                              "cont_clean_date",
                              "disc_date_final",
                              "cont_date_final",
                              "disc_date_pre",
                              "disc_pre_year",
                              "disc_pre_month",
                              "wstation_usaf",
                              "dstation_m",
                              "wstation_wban",
                              "wstation_byear",
                              "wstation_eyear",
                              "fire_mag",
                              "weather_file"])
fire_df=fire_df.dropna()

#renaming for aesthetics
fire_df=fire_df.rename(columns={"fire_name":"Fire Name",
                                "fire_size":"Fire Size",
                                "fire_size_class":"Fire Size Class",
                                "stat_cause_descr":"Fire Cause",
                                "latitude":"Latitude",
                                "longitude":"Longitude",
                                "disc_clean_date":"Date of Discovery",
                                "discovery_month":"Month of Discovery",
                                "putout_time":"Fire Duration",
                                "Temp_pre_30":"Temp 30 Days Prior",
                                "Temp_pre_15":"Temp 15 Days Prior",
                                "Temp_pre_7":"Temp 7 Days Prior",
                                "Temp_cont":"Temp on Containment",
                                "Wind_pre_30":"Wind 30 Days Prior",
                                "Wind_pre_15":"Wind 15 Days Prior",
                                "Wind_pre_7":"Wind 7 Days Prior",
                                "Wind_cont":"Wind on Containment",
                                "Hum_pre_30":"Humidity 30 Days Prior",
                                "Hum_pre_15":"Humidity 15 Days Prior",
                                "Hum_pre_7":"Humidity 7 Days Prior",
                                "Hum_cont":"Humidity on Containment",
                                "Prec_pre_30":"Precipitation 30 Days Prior",
                                "Prec_pre_15":"Precipitation 15 Days Prior",
                                "Prec_pre_7":"Precipitation 7 Days Prior",
                                "Prec_cont":"Precipitation on Containment",
                                "remoteness":"Remoteness"
})

# %%
#convert to farenheit
fire_df["Temp 30 Days Prior"]=(fire_df["Temp 30 Days Prior"] * 9/5) + 32
fire_df["Temp 15 Days Prior"]=(fire_df["Temp 15 Days Prior"] * 9/5) + 32
fire_df["Temp 7 Days Prior"]=(fire_df["Temp 7 Days Prior"] * 9/5) + 32
fire_df["Temp on Containment"]=(fire_df["Temp on Containment"] * 9/5) + 32

# %%
#making Fire Duration row float
fire_df['Fire Duration'] = fire_df['Fire Duration'].str.split(' ').str[0].astype("float")

# %%
#Creating Average dataframes based on Fire Class Size
class_size=fire_df.groupby("Fire Size Class")
wind_df=pd.DataFrame([class_size["Wind 30 Days Prior"].mean(),
                      class_size["Wind 15 Days Prior"].mean(),
                      class_size["Wind 7 Days Prior"].mean(),
                      class_size["Wind on Containment"].mean()]).T
temp_df=pd.DataFrame([class_size["Temp 30 Days Prior"].mean(),
                      class_size["Temp 15 Days Prior"].mean(),
                      class_size["Temp 7 Days Prior"].mean(),
                      class_size["Temp on Containment"].mean()]).T
hum_df=pd.DataFrame([class_size["Humidity 30 Days Prior"].mean(),
                      class_size["Humidity 15 Days Prior"].mean(),
                      class_size["Humidity 7 Days Prior"].mean(),
                      class_size["Humidity on Containment"].mean()]).T
prec_df=pd.DataFrame([class_size["Precipitation 30 Days Prior"].mean(),
                      class_size["Precipitation 15 Days Prior"].mean(),
                      class_size["Precipitation 7 Days Prior"].mean(),
                      class_size["Precipitation on Containment"].mean()]).T

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Duration', x='Wind 30 Days Prior', color='r',label='Wind 30 Days Prior',title="Wind Speed Vs. Fire Duration")    
ax2 = fire_df.plot(kind='scatter', y='Fire Duration', x='Wind 15 Days Prior', color='g',label='Wind 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Duration', x='Wind 7 Days Prior', color='b', label='Wind 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Duration', x='Wind on Containment', color='0',label='Wind on Containment', ax=ax1)
ax1.set_ylabel("Fire Duration (Days)")
ax1.set_xlabel("Wind (m/s)")
# Out:
# Text(0.5, 0, 'Wind (m/s)')

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Size', x='Wind 30 Days Prior', color='r',label='Wind 30 Days Prior',title="Wind Speed Vs. Fire Size")    
ax2 = fire_df.plot(kind='scatter', y='Fire Size', x='Wind 15 Days Prior', color='g',label='Wind 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Size', x='Wind 7 Days Prior', color='b', label='Wind 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Size', x='Wind on Containment', color='0',label='Wind on Containment', ax=ax1)
ax1.set_ylabel("Fire Size (Acre)")
ax1.set_xlabel("Wind (m/s)")
# Out:
# Text(0.5, 0, 'Wind (m/s)')

# %%
x = np.arange(len(wind_df.index))
width = .2
fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width,wind_df["Wind 30 Days Prior"],width, label="Wind 30 Days Prior",color="r")
rects2 = ax.bar(x - width,wind_df["Wind 15 Days Prior"],width, label="Wind 15 Days Prior", color='g')
rects3 = ax.bar(x,wind_df["Wind 7 Days Prior"],width, label="Wind 7 Days Prior", color='b')
rects4 = ax.bar(x+width,wind_df["Wind on Containment"],width, label="Wind on Containment", color='0')
 
ax.set_ylabel('Wind (m/s)')
ax.set_title('Avg Wind Speed of Fire Size Classes')
ax.set_xticks(x)
ax.set_xticklabels(wind_df.index)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))



fig.tight_layout()

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Duration', x='Temp 30 Days Prior', color='r',label='Temp 30 Days Prior',title="Temperature Vs. Fire Duration")    
ax2 = fire_df.plot(kind='scatter', y='Fire Duration', x='Temp 15 Days Prior', color='g',label='Temp 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Duration', x='Temp 7 Days Prior', color='b', label='Temp 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Duration', x='Temp on Containment', color='0',label='Temp on Containment', ax=ax1)
ax1.set_ylabel("Fire Duration (Days)")
ax1.set_xlabel("Temp (F)")
# Out:
# Text(0.5, 0, 'Temp (F)')

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Size', x='Temp 30 Days Prior', color='r',label='Temp 30 Days Prior',title="Temperature Vs. Fire Size")    
ax2 = fire_df.plot(kind='scatter', y='Fire Size', x='Temp 15 Days Prior', color='g',label='Temp 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Size', x='Temp 7 Days Prior', color='b', label='Temp 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Size', x='Temp on Containment', color='0',label='Temp on Containment', ax=ax1)
ax1.set_ylabel("Fire Size (Acre)")
ax1.set_xlabel("Temp (F)")
# Out:
# Text(0.5, 0, 'Temp (F)')

# %%
x = np.arange(len(temp_df.index))
width = .2
fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width,temp_df["Temp 30 Days Prior"],width, label="Temperature 30 Days Prior",color="r")
rects2 = ax.bar(x - width,temp_df["Temp 15 Days Prior"],width, label="Temperature 15 Days Prior", color='g')
rects3 = ax.bar(x,temp_df["Temp 7 Days Prior"],width, label="Temperature 7 Days Prior", color='b')
rects4 = ax.bar(x+width,temp_df["Temp on Containment"],width, label="Temperature on Containment", color='0')
 
ax.set_ylabel('Temperature (F)')
ax.set_title('Avg Temperature of Fire Size Classes')
ax.set_xticks(x)
ax.set_xticklabels(temp_df.index)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))



fig.tight_layout()

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Duration', x='Humidity 30 Days Prior', color='r',label='Humidity 30 Days Prior',title="Humidity Vs. Fire Duration")    
ax2 = fire_df.plot(kind='scatter', y='Fire Duration', x='Humidity 15 Days Prior', color='g',label='Humidity 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Duration', x='Humidity 7 Days Prior', color='b', label='Humidity 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Duration', x='Humidity on Containment', color='0',label='Humidity on Containment', ax=ax1)
ax1.set_ylabel("Fire Duration (Days)")
ax1.set_xlabel("Humidity (%)")
# Out:
# Text(0.5, 0, 'Humidity (%)')

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Size', x='Humidity 30 Days Prior', color='r',label='Humidity 30 Days Prior',title="Humidity Vs. Fire Size")    
ax2 = fire_df.plot(kind='scatter', y='Fire Size', x='Humidity 15 Days Prior', color='g',label='Humidity 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Size', x='Humidity 7 Days Prior', color='b', label='Humidity 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Size', x='Humidity on Containment', color='0',label='Humidity on Containment', ax=ax1)
ax1.set_ylabel("Fire Size (Acre)")
ax1.set_xlabel("Humidity (%)")
# Out:
# Text(0.5, 0, 'Humidity (%)')

# %%
x = np.arange(len(hum_df.index))
width = .2
fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width,hum_df["Humidity 30 Days Prior"],width, label="Humidity 30 Days Prior",color="r")
rects2 = ax.bar(x - width,hum_df["Humidity 15 Days Prior"],width, label="Humidity 15 Days Prior", color='g')
rects3 = ax.bar(x,hum_df["Humidity 7 Days Prior"],width, label="Humidity 7 Days Prior", color='b')
rects4 = ax.bar(x+width,hum_df["Humidity on Containment"],width, label="Humidity on Containment", color='0')
 
ax.set_ylabel('Humidity (%)')
ax.set_title('Avg Humidity of Fire Size Classes')
ax.set_xticks(x)
ax.set_xticklabels(wind_df.index)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))



fig.tight_layout()

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Duration', x='Precipitation 30 Days Prior', color='r',label='Precipitation 30 Days Prior',title="Precipitation Vs. Fire Duration")    
ax2 = fire_df.plot(kind='scatter', y='Fire Duration', x='Precipitation 15 Days Prior', color='g',label='Precipitation 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Duration', x='Precipitation 7 Days Prior', color='b', label='Precipitation 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Duration', x='Precipitation on Containment', color='0',label='Precipitation on Containment', ax=ax1)
ax1.set_ylabel("Fire Duration (Days)")
ax1.set_xlabel("Precipitation (mm)")
# Out:
# Text(0.5, 0, 'Precipitation (mm)')

# %%
ax1 = fire_df.plot(kind='scatter', y='Fire Size', x='Precipitation 30 Days Prior', color='r',label='Precipitation 30 Days Prior',title="Precipitation Vs. Fire Size")    
ax2 = fire_df.plot(kind='scatter', y='Fire Size', x='Precipitation 15 Days Prior', color='g',label='Precipitation 15 Days Prior',ax=ax1)    
ax3 = fire_df.plot(kind='scatter', y='Fire Size', x='Precipitation 7 Days Prior', color='b', label='Precipitation 7 Days Prior',ax=ax1)
ax4=fire_df.plot(kind='scatter', y='Fire Size', x='Precipitation on Containment', color='0',label='Precipitation on Containment', ax=ax1)
ax1.set_ylabel("Fire Size (Acre)")
ax1.set_xlabel("Precipitation (mm)")
# Out:
# Text(0.5, 0, 'Precipitation (mm)')

# %%
x = np.arange(len(prec_df.index))
width = .2
fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width,prec_df["Precipitation 30 Days Prior"],width, label="Precipitation 30 Days Prior",color="r")
rects2 = ax.bar(x - width,prec_df["Precipitation 15 Days Prior"],width, label="Precipitation 15 Days Prior", color='g')
rects3 = ax.bar(x,prec_df["Precipitation 7 Days Prior"],width, label="Precipitation 7 Days Prior", color='b')
rects4 = ax.bar(x+width,prec_df["Precipitation on Containment"],width, label="Precipitation on Containment", color='0')
 
ax.set_ylabel('Precipitation (mm)')
ax.set_title('Avg Precipitation of Fire Size Classes')
ax.set_xticks(x)
ax.set_xticklabels(wind_df.index)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))



fig.tight_layout()
